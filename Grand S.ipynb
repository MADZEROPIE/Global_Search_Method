# %%
# %%cmd
# md build
# cd build
# cmake ..

# %%
# %%cmd
# cd build
# cmake --build . --config RELEASE
# Out:
# Microsoft Windows [Version 10.0.18363.1256]
# (c) Љ®аЇ®а жЁп Њ ©Єа®б®дв (Microsoft Corporation), 2019. ‚бҐ Їа ў  § йЁйҐ­л.
#
# C:\Users\MADZEROPIE\Downloads\GLOP2_1>cd build
#
# C:\Users\MADZEROPIE\Downloads\GLOP2_1\build>cmake --build . --config RELEASE
# Microsoft (R) Build Engine ўҐабЁЁ 16.8.3+39993bd9d ¤«п .NET Framework
# (C) Љ®аЇ®а жЁп Њ ©Єа®б®дв (Microsoft Corporation). ‚бҐ Їа ў  § йЁйҐ­л.
#
#   sample_agp.cpp
# C:\Users\MADZEROPIE\Downloads\GLOP2_1\sample_src\sample_agp.cpp(112,1): warning C4267: =: ЇаҐ®Ўа §®ў ­ЁҐ Ё§ "size_t" ў "int"; ў®§¬®¦­  Ї®вҐап ¤ ­­ле [C:\Users\MADZEROPIE\Downloads\GLOP2_1\build\builder_sample.vcxproj]
# C:\Users\MADZEROPIE\Downloads\GLOP2_1\sample_src\sample_agp.cpp(359,41): warning C4267:  аЈг¬Ґ­в: ЇаҐ®Ўа §®ў ­ЁҐ Ё§ "size_t" ў "int"; ў®§¬®¦­  Ї®вҐап ¤ ­­ле [C:\Users\MADZEROPIE\Downloads\GLOP2_1\build\builder_sample.vcxproj]
# C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.28.29333\include\utility(313,39): warning C4244: =: ЇаҐ®Ўа §®ў ­ЁҐ "_Ty" ў "_Ty1", ў®§¬®¦­  Ї®вҐап ¤ ­­ле [C:\Users\MADZEROPIE\Downloads\GLOP2_1\build\builder_sample.vcxproj]
#           with
#           [
#               _Ty=double
#           ]
#           and
#           [
#               _Ty1=int
#           ]
# C:\Users\MADZEROPIE\Downloads\GLOP2_1\sample_src\sample_agp.cpp(140): message : ўлЇ®«­пҐвбп Є®¬ЇЁ«пжЁп ббл«ЄЁ ­  нЄ§Ґ¬Ї«па и Ў«®­ дг­ЄжЁЁ "std::pair<int,double> &std::pair<int,double>::operator =<double,double,0>(std::pair<double,double> &&) noexcept" [C:\Users\MADZEROPIE\Downloads\GLOP2_1\build\builder_sample.vcxproj]
# C:\Users\MADZEROPIE\Downloads\GLOP2_1\sample_src\sample_agp.cpp(140): message : ўлЇ®«­пҐвбп Є®¬ЇЁ«пжЁп ббл«ЄЁ ­  нЄ§Ґ¬Ї«па и Ў«®­ дг­ЄжЁЁ "std::pair<int,double> &std::pair<int,double>::operator =<double,double,0>(std::pair<double,double> &&) noexcept" [C:\Users\MADZEROPIE\Downloads\GLOP2_1\build\builder_sample.vcxproj]
# LINK : fatal error LNK1104: ­Ґ г¤ Ґвбп ®вЄалвм д ©« "C:\Users\MADZEROPIE\Downloads\GLOP2_1\build\Release\builder_sample.exe" [C:\Users\MADZEROPIE\Downloads\GLOP2_1\build\builder_sample.vcxproj]
#
# C:\Users\MADZEROPIE\Downloads\GLOP2_1\build>

# %%
import subprocess
str_of_r=["2.0","3.0","4.0"]

s="res"

for i in str_of_r:
    subprocess.run([r".\build\Release\builder_sample.exe",s+i,i])

# %%
import pandas as pd
import matplotlib.pyplot as plt

names=["Hansen","Hill","Shekel"]

print(names[0]);

for i in str_of_r:
    #print("r =",i)
    data=pd.read_csv("./"+s+i+names[0]+".csv")
    data.columns=["x","y"]
    plt.plot(data["x"], data["y"], label = f"r = {i}")# , kind="scatter")
    
plt.ylim(bottom=0,top=1) 
plt.xlim(left=0)
    
plt.legend()
plt.show()
# Out:
# Hansen

# %%
print(names[1]);
for i in str_of_r:
    #print("r =",i)
    data=pd.read_csv("./"+s+i+names[1]+".csv")
    data.columns=["x","y"]
    plt.plot(data["x"], data["y"], label = f"r = {i}")# , kind="scatter")
    plt.ylim(bottom=0,top=1)
    plt.xlim(left=0)
    
plt.legend()
plt.show()
# Out:
# Hill

# %%
print(names[2]);
for i in str_of_r:
    #print("r =",i)
    data=pd.read_csv("./"+s+i+names[2]+".csv")
    data.columns=["x","y"]
    plt.plot(data["x"], data["y"], label = f"r = {i}")# , kind="scatter")
    plt.ylim(bottom=0,top=1)
plt.xlim(left=0, right=130)
    
plt.legend()
plt.show()
# Out:
# Shekel
